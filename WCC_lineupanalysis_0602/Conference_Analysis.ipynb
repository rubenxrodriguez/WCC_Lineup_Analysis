# %% [markdown]
# ## Assuming you've already ran 'Lineup_Merge.py' and have your progression data in a folder called 'output'

# %%
import pandas as pd
import os
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load Data Function

# %%
teams_list = ['Akron', 'Ball St.', 'Bowling Green', 'Buffalo', 'Central Mich.',
            'Eastern Mich.', 'Kent St.', 'Miami (OH)', 'NIU', 'Ohio',
            'Toledo', 'Western Mich.','Brown', 'Columbia', 'Cornell', 'Dartmouth',
            'Harvard', 'Penn', 'Princeton', 'Yale','Gonzaga', 'LMU (CA)', 'Oregon St.', 'Pacific',
            'Pepperdine', 'Portland', "Saint Mary's (CA)", 'San Diego',
            'San Francisco', 'Santa Clara', 'Washington St.']

CONFERENCE_MAPPING = {
    'MAC': ['Akron', 'Ball St.', 'Bowling Green', 'Buffalo', 'Central Mich.',
            'Eastern Mich.', 'Kent St.', 'Miami (OH)', 'NIU', 'Ohio',
            'Toledo', 'Western Mich.'],
    'IVY': ['Brown', 'Columbia', 'Cornell', 'Dartmouth',
            'Harvard', 'Penn', 'Princeton', 'Yale'],
    'WCC': ['Gonzaga', 'LMU (CA)', 'Oregon St.', 'Pacific',
            'Pepperdine', 'Portland', "Saint Mary's (CA)", 'San Diego',
            'San Francisco', 'Santa Clara', 'Washington St.']
}

def load_all_team_data(teams_list):
    """Load and merge all team progression and top lineup data"""
    # Initialize containers
    all_progression = []
    all_top_lineups = []
    TEAM_TO_CONFERENCE = {}
    for conf, teams in CONFERENCE_MAPPING.items():
        for t in teams:
            TEAM_TO_CONFERENCE[t] = conf
    for team in teams_list:
        # Load progression data
        prog_file = f"output/{team.replace('/', '_')}_progression.csv"  # Handle special chars
        if Path(prog_file).exists():
            prog_df = pd.read_csv(prog_file)
            prog_df['team'] = team
            # Add conference column using mapping
            prog_df['conference'] = TEAM_TO_CONFERENCE.get(team, 'Unknown')
            all_progression.append(prog_df)
        
        # Load top lineups data
        top_file = f"output/{team.replace('/', '_')}_top_lineups.csv"
        if Path(top_file).exists():
            top_df = pd.read_csv(top_file)
            top_df['team'] = team
            # Add conference column using mapping
            top_df['conference'] = TEAM_TO_CONFERENCE.get(team, 'Unknown')
            all_top_lineups.append(top_df)
        
    # Combine all data
    combined_progression = pd.concat(all_progression, ignore_index=True)
    #drop 'interval' column if it exists
    if 'interval' in combined_progression.columns:
        combined_progression.drop(columns=['interval'], inplace=True)
    combined_top_lineups = pd.concat(all_top_lineups, ignore_index=True)
    
    combined_progression.fillna(0, inplace=True)
    combined_top_lineups.fillna(0, inplace=True)
    
    return combined_progression, combined_top_lineups

# %% [markdown]
# ### Load all data

# %%
combined_progression, combined_top_lineups = load_all_team_data(teams_list)

# %% [markdown]
# ## Lineups with more than delta = 50 minutes in any given interval

# %%
delta = 50

lineups_over_50_per_interval = combined_progression[combined_progression['minutes'] > delta][['lineup','conference', 'team', 'interval_num', 'minutes', 'plusminus_per40']].sort_values(
    by='plusminus_per40', ascending=False
)


styled = lineups_over_50_per_interval.style.background_gradient(
    cmap = 'RdYlGn',
    subset = ['plusminus_per40']
).format(
    {
    'plusminus_per40': '{:.1f}',
    'minutes': '{:.0f}'
    }
)
display(styled)
print('Number of distinct teams : ',len(combined_progression['team'].unique()))
print('\n'*2)
print('Number of Lineups with over 50 minutes in an interval : ', len(lineups_over_50_per_interval))
# Out:
# <style type="text/css">
# #T_4c761_row0_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4c761_row1_col5 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_4c761_row2_col5 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_4c761_row3_col5 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_4c761_row4_col5 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_4c761_row5_col5 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_4c761_row6_col5 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_4c761_row7_col5 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_4c761_row8_col5 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_4c761_row9_col5 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_4c761_row10_col5 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_4c761_row11_col5 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_4c761_row12_col5 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_4c761_row13_col5 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_4c761_row14_col5 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_4c761_row15_col5 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_4c761_row16_col5 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_4c761_row17_col5 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_4c761_row18_col5 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_4c761_row19_col5 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_4c761_row20_col5 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_4c761_row21_col5, #T_4c761_row22_col5, #T_4c761_row23_col5 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_4c761_row24_col5 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_4c761_row25_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_4c761_row26_col5 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_4c761_row27_col5 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_4c761_row28_col5 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_4c761_row29_col5 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_4c761_row30_col5 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_4c761_row31_col5, #T_4c761_row32_col5 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_4c761_row33_col5 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_4c761_row34_col5, #T_4c761_row35_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_4c761_row36_col5 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_4c761_row37_col5 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_4c761_row38_col5 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_4c761_row39_col5 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_4c761_row40_col5 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_4c761_row41_col5 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_4c761_row42_col5 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_4c761_row43_col5, #T_4c761_row44_col5 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_4c761_row45_col5, #T_4c761_row46_col5, #T_4c761_row47_col5 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_4c761_row48_col5 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_4c761_row49_col5 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_4c761_row50_col5 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_4c761_row51_col5 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_4c761_row52_col5, #T_4c761_row53_col5, #T_4c761_row54_col5 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_4c761_row55_col5, #T_4c761_row56_col5 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_4c761_row57_col5 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_4c761_row58_col5 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_4c761_row59_col5 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_4c761_row60_col5 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_4c761_row61_col5, #T_4c761_row62_col5 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_4c761_row63_col5 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_4c761_row64_col5 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_4c761_row65_col5 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_4c761_row66_col5 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_4c761_row67_col5 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_4c761_row68_col5 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_4c761_row69_col5 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_4c761_row70_col5 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_4c761_row71_col5 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_4c761_row72_col5 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_4c761_row73_col5 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_4c761_row74_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c761">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c761_level0_col0" class="col_heading level0 col0" >lineup</th>
#       <th id="T_4c761_level0_col1" class="col_heading level0 col1" >conference</th>
#       <th id="T_4c761_level0_col2" class="col_heading level0 col2" >team</th>
#       <th id="T_4c761_level0_col3" class="col_heading level0 col3" >interval_num</th>
#       <th id="T_4c761_level0_col4" class="col_heading level0 col4" >minutes</th>
#       <th id="T_4c761_level0_col5" class="col_heading level0 col5" >plusminus_per40</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c761_level0_row0" class="row_heading level0 row0" >4605</th>
#       <td id="T_4c761_row0_col0" class="data row0 col0" >HTUR-GAND-LCHA-SGLE-EROD</td>
#       <td id="T_4c761_row0_col1" class="data row0 col1" >IVY</td>
#       <td id="T_4c761_row0_col2" class="data row0 col2" >Harvard</td>
#       <td id="T_4c761_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_4c761_row0_col4" class="data row0 col4" >68</td>
#       <td id="T_4c761_row0_col5" class="data row0 col5" >44.4</td>
#     </tr>
#     <tr>
#       <th id="T_4c761_level0_row1" class="row_heading level0 row1" >6855</th>
#       <td id="T_4c761_row1_col0" class="data row1 col0" >MMEE-AMAR-ESHE-MBUR-THUL</td>
#       <td id="T_4c761_row1_col1" class="data row1 col1" >WCC</td>
#       <td id="T_4c761_row1_col2" class="data row1 col2" >Portland</td>
#       <td id="T_4c761_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_4c761_row1_col4" class="data row1 col4" >68</td>
#       <td id="T_4c761_row1_col5" class="data row1 col5" >36.5</td>
#     </tr>
#     <tr>
#       <th id="T_4c761_level0_row2" class="row_heading level0 row2" >3823</th>
#       <td id="T_4c761_row2_col0" class="data row2 col0" >MAVL-KHEN-RWEI-CCOL-SRAF</td>
#       <td id="T_4c761_row2_col1" class="data row2 col1" >IVY</td>
#       <td id="T_4c761_row2_col2" class="data row2 col2" >Columbia</td>
#       <td id="T_4c761_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_4c761_row2_col4" class="data row2 col4" >54</td>
#       <td id="T_4c761_row2_col5" class="data row2 col5" >24.6</td>
#     </tr>
#     <tr>
#       <th id="T_4c761_level0_row3" class="row_heading level0 row3" >6947</th>
#       <td id="T_4c761_row3_col0" class="data row3 col0" >MMEE-AMAR-ESHE-MBUR-THUL</td>
#       <td id="T_4c761_row3_col1" class="data row3 col1" >WCC</td>
#       <td id="T_4c761_row3_col2" class="data row3 col2" >Portland</td>
#       <td id="T_4c761_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_4c761_row3_col4" class="data row3 col4" >114</td>
#       <td id="T_4c761_row3_col5" class="data row3 col5" >23.8</td>
#     </tr>
#     <tr>
#       <th id="T_4c761_level0_row4" class="row_heading level0 row4" >4991</th>
#       <td id="T_4c761_row4_col0" class="data row4 col0" >ACHE-SBEL-OHUT-FTAL-PHIL</td>
#       <td id="T_4c761_row4_col1" class="data row4 col1" >IVY</td>
#       <td id="T_4c761_row4_col2" class="data row4 col2" >Princeton</td>
#       <td id="T_4c761_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_4c761_row4_col4" class="data row4 col4" >56</td>
#       <td id="T_4c761_row4_col5" class="data row4 col5" >23.6</td>
#     </tr>
# Number of distinct teams :  31
#
#
#
# Number of Lineups with over 50 minutes in an interval :  75

# %% [markdown]
# ## Lineups with more than delta = 50 minutes in any given interval (sorted by interval)

# %%
delta = 50

lineups_over_50_per_interval = combined_progression[combined_progression['minutes'] > delta][['lineup', 'team', 'interval_num', 'minutes', 'plusminus_per40']].sort_values(
    by='interval_num', ascending=True
)


styled = lineups_over_50_per_interval.style.background_gradient(
    cmap = 'RdYlGn',
    subset = ['plusminus_per40']
).format(
    {
    'plusminus_per40': '{:.1f}',
    'minutes': '{:.0f}'
    }
)
display(styled)

print(lineups_over_50_per_interval.aggregate(
    {
        'minutes': ['mean','std','max']
    }
))
print('Number of distinct teams : ',len(combined_progression['team'].unique()))
print('\n'*2)
print('Number of Lineups with over 50 minutes in an interval : ', len(lineups_over_50_per_interval))
# Out:
# <style type="text/css">
# #T_566fd_row0_col4, #T_566fd_row29_col4 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_566fd_row1_col4 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_566fd_row2_col4 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_566fd_row3_col4, #T_566fd_row47_col4, #T_566fd_row57_col4 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_566fd_row4_col4 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_566fd_row5_col4, #T_566fd_row39_col4 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_566fd_row6_col4, #T_566fd_row61_col4, #T_566fd_row63_col4 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_566fd_row7_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_566fd_row8_col4 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_566fd_row9_col4 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_566fd_row10_col4 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_566fd_row11_col4, #T_566fd_row37_col4, #T_566fd_row51_col4 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_566fd_row12_col4 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_566fd_row13_col4 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_566fd_row14_col4 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_566fd_row15_col4 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_566fd_row16_col4 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_566fd_row17_col4 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_566fd_row18_col4 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_566fd_row19_col4 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_566fd_row20_col4 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_566fd_row21_col4 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_566fd_row22_col4, #T_566fd_row54_col4 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_566fd_row23_col4 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_566fd_row24_col4 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_566fd_row25_col4 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_566fd_row26_col4, #T_566fd_row71_col4 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_566fd_row27_col4 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_566fd_row28_col4 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_566fd_row30_col4 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_566fd_row31_col4 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_566fd_row32_col4 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_566fd_row33_col4 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_566fd_row34_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_566fd_row35_col4 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_566fd_row36_col4 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_566fd_row38_col4 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_566fd_row40_col4 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_566fd_row41_col4, #T_566fd_row48_col4 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_566fd_row42_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_566fd_row43_col4 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_566fd_row44_col4 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_566fd_row45_col4 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_566fd_row46_col4 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_566fd_row49_col4 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_566fd_row50_col4 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_566fd_row52_col4 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_566fd_row53_col4 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_566fd_row55_col4 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_566fd_row56_col4 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_566fd_row58_col4 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_566fd_row59_col4 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_566fd_row60_col4 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_566fd_row62_col4 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_566fd_row64_col4 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_566fd_row65_col4 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_566fd_row66_col4 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_566fd_row67_col4 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_566fd_row68_col4 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_566fd_row69_col4 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_566fd_row70_col4 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_566fd_row72_col4 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_566fd_row73_col4 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_566fd_row74_col4 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# </style>
# <table id="T_566fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_566fd_level0_col0" class="col_heading level0 col0" >lineup</th>
#       <th id="T_566fd_level0_col1" class="col_heading level0 col1" >team</th>
#       <th id="T_566fd_level0_col2" class="col_heading level0 col2" >interval_num</th>
#       <th id="T_566fd_level0_col3" class="col_heading level0 col3" >minutes</th>
#       <th id="T_566fd_level0_col4" class="col_heading level0 col4" >plusminus_per40</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_566fd_level0_row0" class="row_heading level0 row0" >289</th>
#       <td id="T_566fd_row0_col0" class="data row0 col0" >LAUS-ABEC-MBIS-ESTU-MKIE</td>
#       <td id="T_566fd_row0_col1" class="data row0 col1" >Ball St.</td>
#       <td id="T_566fd_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_566fd_row0_col3" class="data row0 col3" >69</td>
#       <td id="T_566fd_row0_col4" class="data row0 col4" >-9.3</td>
#     </tr>
#     <tr>
#       <th id="T_566fd_level0_row1" class="row_heading level0 row1" >4166</th>
#       <td id="T_566fd_row1_col0" class="data row1 col0" >VPAG-ZOZE-AELD-OAUS-CMEY</td>
#       <td id="T_566fd_row1_col1" class="data row1 col1" >Dartmouth</td>
#       <td id="T_566fd_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_566fd_row1_col3" class="data row1 col3" >73</td>
#       <td id="T_566fd_row1_col4" class="data row1 col4" >-17.1</td>
#     </tr>
#     <tr>
#       <th id="T_566fd_level0_row2" class="row_heading level0 row2" >4029</th>
#       <td id="T_566fd_row2_col0" class="data row2 col0" >AKIL-KLAN-CJAC-SPAR-EPAP</td>
#       <td id="T_566fd_row2_col1" class="data row2 col1" >Cornell</td>
#       <td id="T_566fd_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_566fd_row2_col3" class="data row2 col3" >72</td>
#       <td id="T_566fd_row2_col4" class="data row2 col4" >3.9</td>
#     </tr>
#     <tr>
#       <th id="T_566fd_level0_row3" class="row_heading level0 row3" >3979</th>
#       <td id="T_566fd_row3_col0" class="data row3 col0" >AKIL-KLAN-CJAC-RKAU-EPAP</td>
#       <td id="T_566fd_row3_col1" class="data row3 col1" >Cornell</td>
#       <td id="T_566fd_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_566fd_row3_col3" class="data row3 col3" >56</td>
#       <td id="T_566fd_row3_col4" class="data row3 col4" >-0.7</td>
#     </tr>
#     <tr>
#       <th id="T_566fd_level0_row4" class="row_heading level0 row4" >5286</th>
#       <td id="T_566fd_row4_col0" class="data row4 col0" >ALEE-MCHA-KCAP-MEGG-GTHY</td>
#       <td id="T_566fd_row4_col1" class="data row4 col1" >Yale</td>
#       <td id="T_566fd_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_566fd_row4_col3" class="data row4 col3" >70</td>
#       <td id="T_566fd_row4_col4" class="data row4 col4" >-11.4</td>
#     </tr>
#     <tr>
#       <th id="T_566fd_level0_row5" class="row_heading level0 row5" >3648</th>
#       <td id="T_566fd_row5_col0" class="data row5 col0" >KHEN-RWEI-PPAG-CCOL-SRAF</td>
#       <td id="T_566fd_row5_col1" class="data row5 col1" >Columbia</td>
#       <td id="T_566fd_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_566fd_row5_col3" class="data row5 col3" >101</td>
#       <td id="T_566fd_row5_col4" class="data row
#          minutes
# mean   76.311200
# std    24.733915
# max   154.890000
# Number of distinct teams :  31
#
#
#
# Number of Lineups with over 50 minutes in an interval :  75

# %% [markdown]
# ## Team and Lineups with more than 50 minutes played full season

# %%
# First, compute total minutes per lineup
lineup_total_minutes = (
    combined_progression.groupby(['team', 'lineup'])['minutes']
    .sum()
    .reset_index()
    .rename(columns={'minutes': 'total_minutes'})
)

# Filter to only lineups that played more than 50 minutes total
full_season_lineups = lineup_total_minutes[lineup_total_minutes['total_minutes'] > delta]

# Count lineups per team
team_full_season_counts = (
    full_season_lineups.groupby('team')
    .size()
    .reset_index(name='num_lineups_over_50')
    .sort_values(by= 'num_lineups_over_50', ascending = True)
)

display(team_full_season_counts)
print('Average number of lineups with more than 50 minutes: ',team_full_season_counts['num_lineups_over_50'].mean().round(2))
print(team_full_season_counts.aggregate(
    {
        'num_lineups_over_50': ['mean','std','max']
    }
))
# Out:
#                  team  num_lineups_over_50
# 29      Western Mich.                    1
# 11            Harvard                    1
# 30               Yale                    2
# 14         Miami (OH)                    2
# 5       Central Mich.                    2
# 16               Ohio                    3
# 13           LMU (CA)                    3
# 12           Kent St.                    3
# 22          Princeton                    3
# 9       Eastern Mich.                    3
# 8           Dartmouth                    3
# 23  Saint Mary's (CA)                    3
# 3               Brown                    3
# 2       Bowling Green                    3
# 24          San Diego                    4
# 25      San Francisco                    4
# 27             Toledo                    4
# 20         Pepperdine                    4
# 19               Penn                    4
# 0               Akron                    4
# 18            Pacific                    4
# 17         Oregon St.                    5
# 21           Portland                    5
# 10            Gonzaga                    5
# 6            Columbia                    5
# 1            Ball St.                    5
# 28     Washington St.                    5
# 15                NIU                    6
# 7             Cornell                    7
# 4             Buffalo                    7
# 26        Santa Clara                    8
# Average number of lineups with more than 50 minutes:  3.9
#       num_lineups_over_50
# mean             3.903226
# std              1.660418
# max              8.000000

# %% [markdown]
# ## Each Team's Top 2 Lineups (By Plusminus-Per40)

# %%
# Get top 2 lineups per team by plusminus_per40_mean
top2_per_team = (
    combined_top_lineups
    .sort_values(['team', 'plusminus_per40'], ascending=[True, False])
    .groupby('team')
    .head(2)
    [['team', 'lineup', 'minutes', 'plusminus_per40']]
    
)

# Style the table
styled_top2 = top2_per_team.style.background_gradient(
    cmap='RdYlGn',
    subset=['plusminus_per40']
).format({
    'plusminus_per40': '{:.1f}',
    'minutes': '{:.0f}',
})

display(styled_top2)
# Out:
# <style type="text/css">
# #T_44707_row0_col3 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_44707_row1_col3, #T_44707_row32_col3 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_44707_row2_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_44707_row3_col3 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_44707_row4_col3 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_44707_row5_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_44707_row6_col3, #T_44707_row31_col3 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_44707_row7_col3 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_44707_row8_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_44707_row9_col3 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_44707_row10_col3 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_44707_row11_col3 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_44707_row12_col3 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_44707_row13_col3 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_44707_row14_col3 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_44707_row15_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_44707_row16_col3 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_44707_row17_col3 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_44707_row18_col3 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_44707_row19_col3 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_44707_row20_col3, #T_44707_row60_col3 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_44707_row21_col3 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_44707_row22_col3 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_44707_row23_col3, #T_44707_row28_col3 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_44707_row24_col3 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_44707_row25_col3, #T_44707_row41_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_44707_row26_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_44707_row27_col3, #T_44707_row34_col3 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_44707_row29_col3 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_44707_row30_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_44707_row33_col3 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_44707_row35_col3, #T_44707_row39_col3 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_44707_row36_col3 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_44707_row37_col3 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_44707_row38_col3 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_44707_row40_col3, #T_44707_row51_col3 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_44707_row42_col3 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_44707_row43_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_44707_row44_col3 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_44707_row45_col3 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_44707_row46_col3 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_44707_row47_col3 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_44707_row48_col3 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_44707_row49_col3 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_44707_row50_col3, #T_44707_row56_col3 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_44707_row52_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_44707_row53_col3 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_44707_row54_col3 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_44707_row55_col3, #T_44707_row61_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_44707_row57_col3 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_44707_row58_col3 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_44707_row59_col3 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_44707">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44707_level0_col0" class="col_heading level0 col0" >team</th>
#       <th id="T_44707_level0_col1" class="col_heading level0 col1" >lineup</th>
#       <th id="T_44707_level0_col2" class="col_heading level0 col2" >minutes</th>
#       <th id="T_44707_level0_col3" class="col_heading level0 col3" >plusminus_per40</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44707_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_44707_row0_col0" class="data row0 col0" >Akron</td>
#       <td id="T_44707_row0_col1" class="data row0 col1" >EHAL-AMOB-SBRO-MVEJ-LTAP</td>
#       <td id="T_44707_row0_col2" class="data row0 col2" >33</td>
#       <td id="T_44707_row0_col3" class="data row0 col3" >14.6</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_44707_row1_col0" class="data row1 col0" >Akron</td>
#       <td id="T_44707_row1_col1" class="data row1 col1" >EHAL-AMOB-SBRO-MVEJ-NCLA</td>
#       <td id="T_44707_row1_col2" class="data row1 col2" >42</td>
#       <td id="T_44707_row1_col3" class="data row1 col3" >11.4</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_44707_row2_col0" class="data row2 col0" >Ball St.</td>
#       <td id="T_44707_row2_col1" class="data row2 col1" >LAUS-ABEC-GKIN-ARIC-MKIE</td>
#       <td id="T_44707_row2_col2" class="data row2 col2" >35</td>
#       <td id="T_44707_row2_col3" class="data row2 col3" >32.3</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_44707_row3_col0" class="data row3 col0" >Ball St.</td>
#       <td id="T_44707_row3_col1" class="data row3 col1" >LAUS-ABEC-ARIC-ESTU-MKIE</td>
#       <td id="T_44707_row3_col2" class="data row3 col2" >90</td>
#       <td id="T_44707_row3_col3" class="data row3 col3" >23.2</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row4" class="row_heading level0 row4" >31</th>
#       <td id="T_44707_row4_col0" class="data row4 col0" >Bowling Green</td>
#       <td id="T_44707_row4_col1" class="data row4 col1" >AVEL-JDON-PKOH-JFEA-EPOR</td>
#       <td id="T_44707_row4_col2" class="data row4 col2" >31</td>
#       <td id="T_44707_row4_col3" class="data row4 col3" >18.1</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_44707_row5_col0" class="data row5 col0" >Bowling Green</td>
#       <td id="T_44707_row5_col1" class="data row5 col1" >AVEL-JDON-PKOH-EPOR-KMCG</td>
#       <td id="T_44707_row5_col2" class="data row5 col2" >24</td>
#       <td id="T_44707_row5_col3" class="data row5 col3" >13.5</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row6" class="row_heading level0 row6" >154</th>
#       <td id="T_44707_row6_col0" class="data row6 col0" >Brown</td>
#       <td id="T_44707_row6_col1" class="data row6 col1" >IMAU-GARN-GPOW-AMOR-GAIE</td>
#       <td id="T_44707_row6_col2" class="data row6 col2" >19</td>
#       <td id="T_44707_row6_col3" class="data row6 col3" >19.3</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row7" class="row_heading level0 row7" >149</th>
#       <td id="T_44707_row7_col0" class="data row7 col0" >Brown</td>
#       <td id="T_44707_row7_col1" class="data row7 col1" >IMAU-GARN-GPOW-OYOU-GAIE</td>
#       <td id="T_44707_row7_col2" class="data row7 col2" >47</td>
#       <td id="T_44707_row7_col3" class="data row7 col3" >13.7</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row8" class="row_heading level0 row8" >43</th>
#       <td id="T_44707_row8_col0" class="data row8 col0" >Buffalo</td>
#       <td id="T_44707_row8_col1" class="data row8 col1" >CWAT-PLOP-THAR-KLEW-ADAV</td>
#       <td id="T_44707_row8_col2" class="data row8 col2" >44</td>
#       <td id="T_44707_row8_col3" class="data row8 col3" >41.8</td>
#     </tr>
#     <tr>
#       <th id="T_44707_level0_row9" class="row_heading level0 row9" >47</th>
#       <td id="T_44707_row9_col0" class="data row9 col0" >Buffalo</td>
#       <td id="T

# %% [markdown]
# ## Get top 2 lineups per team by plusminus_per40, but only for lineups with at least 50 minutes played

# %%
# Get top 2 lineups per team by plusminus_per40, but only for lineups with at least 50 minutes played

min_minutes = 50

top2_per_team_50min = (
    combined_top_lineups[combined_top_lineups['minutes'] >= min_minutes]
    .sort_values(['team', 'plusminus_per40'], ascending=[True, False])
    .groupby('team')
    .head(2)
    [['team', 'lineup', 'minutes', 'plusminus_per40']]
)

# Style the table for better visualization
styled_top2_50min = top2_per_team_50min.style.background_gradient(
    cmap='RdYlGn',
    subset=['plusminus_per40']
).format({
    'plusminus_per40': '{:.1f}',
    'minutes': '{:.0f}',
})

display(styled_top2_50min)
# Out:
# <style type="text/css">
# #T_e9271_row0_col3, #T_e9271_row39_col3 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_e9271_row1_col3 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_e9271_row2_col3 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_e9271_row3_col3, #T_e9271_row24_col3 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_e9271_row4_col3 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_e9271_row5_col3 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_e9271_row6_col3, #T_e9271_row14_col3 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_e9271_row7_col3 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_e9271_row8_col3 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_e9271_row9_col3 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_e9271_row10_col3 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_e9271_row11_col3 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_e9271_row12_col3 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_e9271_row13_col3, #T_e9271_row44_col3 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_e9271_row15_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_e9271_row16_col3 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_e9271_row17_col3 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_e9271_row18_col3 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_e9271_row19_col3 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_e9271_row20_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e9271_row21_col3 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_e9271_row22_col3, #T_e9271_row55_col3 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_e9271_row23_col3, #T_e9271_row49_col3 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_e9271_row25_col3, #T_e9271_row47_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_e9271_row26_col3, #T_e9271_row38_col3 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_e9271_row27_col3 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_e9271_row28_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_e9271_row29_col3, #T_e9271_row43_col3 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_e9271_row30_col3 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_e9271_row31_col3, #T_e9271_row32_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e9271_row33_col3 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_e9271_row34_col3 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_e9271_row35_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_e9271_row36_col3 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_e9271_row37_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_e9271_row40_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_e9271_row41_col3 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_e9271_row42_col3 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_e9271_row45_col3 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_e9271_row46_col3, #T_e9271_row56_col3 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_e9271_row48_col3 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_e9271_row50_col3 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_e9271_row51_col3 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_e9271_row52_col3 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_e9271_row53_col3 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_e9271_row54_col3 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_e9271_row57_col3 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_e9271_row58_col3 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_e9271_row59_col3 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e9271">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9271_level0_col0" class="col_heading level0 col0" >team</th>
#       <th id="T_e9271_level0_col1" class="col_heading level0 col1" >lineup</th>
#       <th id="T_e9271_level0_col2" class="col_heading level0 col2" >minutes</th>
#       <th id="T_e9271_level0_col3" class="col_heading level0 col3" >plusminus_per40</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9271_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9271_row0_col0" class="data row0 col0" >Akron</td>
#       <td id="T_e9271_row0_col1" class="data row0 col1" >EHAL-AMOB-ZRAS-SBRO-NCLA</td>
#       <td id="T_e9271_row0_col2" class="data row0 col2" >80</td>
#       <td id="T_e9271_row0_col3" class="data row0 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9271_row1_col0" class="data row1 col0" >Akron</td>
#       <td id="T_e9271_row1_col1" class="data row1 col1" >EHAL-ZRAS-SBRO-MVEJ-NCLA</td>
#       <td id="T_e9271_row1_col2" class="data row1 col2" >80</td>
#       <td id="T_e9271_row1_col3" class="data row1 col3" >-3.5</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_e9271_row2_col0" class="data row2 col0" >Ball St.</td>
#       <td id="T_e9271_row2_col1" class="data row2 col1" >LAUS-ABEC-ARIC-ESTU-MKIE</td>
#       <td id="T_e9271_row2_col2" class="data row2 col2" >90</td>
#       <td id="T_e9271_row2_col3" class="data row2 col3" >23.2</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_e9271_row3_col0" class="data row3 col0" >Ball St.</td>
#       <td id="T_e9271_row3_col1" class="data row3 col1" >LAUS-ABEC-MBIS-ARIC-MKIE</td>
#       <td id="T_e9271_row3_col2" class="data row3 col2" >279</td>
#       <td id="T_e9271_row3_col3" class="data row3 col3" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_e9271_row4_col0" class="data row4 col0" >Bowling Green</td>
#       <td id="T_e9271_row4_col1" class="data row4 col1" >LFLE-AVEL-PKOH-EPOR-KMCG</td>
#       <td id="T_e9271_row4_col2" class="data row4 col2" >134</td>
#       <td id="T_e9271_row4_col3" class="data row4 col3" >11.7</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row5" class="row_heading level0 row5" >24</th>
#       <td id="T_e9271_row5_col0" class="data row5 col0" >Bowling Green</td>
#       <td id="T_e9271_row5_col1" class="data row5 col1" >LFLE-AVEL-JDON-PKOH-EPOR</td>
#       <td id="T_e9271_row5_col2" class="data row5 col2" >197</td>
#       <td id="T_e9271_row5_col3" class="data row5 col3" >6.9</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row6" class="row_heading level0 row6" >144</th>
#       <td id="T_e9271_row6_col0" class="data row6 col0" >Brown</td>
#       <td id="T_e9271_row6_col1" class="data row6 col1" >IMAU-GARN-OYOU-ENEL-GAIE</td>
#       <td id="T_e9271_row6_col2" class="data row6 col2" >103</td>
#       <td id="T_e9271_row6_col3" class="data row6 col3" >8.9</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row7" class="row_heading level0 row7" >146</th>
#       <td id="T_e9271_row7_col0" class="data row7 col0" >Brown</td>
#       <td id="T_e9271_row7_col1" class="data row7 col1" >IMAU-GARN-AMOR-OYOU-ENEL</td>
#       <td id="T_e9271_row7_col2" class="data row7 col2" >57</td>
#       <td id="T_e9271_row7_col3" class="data row7 col3" >1.4</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row8" class="row_heading level0 row8" >38</th>
#       <td id="T_e9271_row8_col0" class="data row8 col0" >Buffalo</td>
#       <td id="T_e9271_row8_col1" class="data row8 col1" >LCOR-CWAT-THAR-KLEW-JBEA</td>
#       <td id="T_e9271_row8_col2" class="data row8 col2" >104</td>
#       <td id="T_e9271_row8_col3" class="data row8 col3" >18.0</td>
#     </tr>
#     <tr>
#       <th id="T_e9271_level0_row9" class="row_heading level0 row9" >40</th>
#       <td id="T_e9271_row9_col0" class="data row9 col0" >Buffalo</td>
#       <td id="T_e9271_row9_col1" class="data row9 col1" >LCOR-CWAT-THAR-KLEW-ASEA</td>
#       <td id="T_e9271_row9_col2" class="data row9 col2" >97</td>
#       <td id="T_e9271_row9_col3" class="data row9 col3

# %% [markdown]
# ## Conference-Wide Analysis Pipeline

# %%
import numpy as np
def analyze_conference(progression_df, top_lineups_df):
    """Complete analysis pipeline for WCC"""
    # 1. Filter to only include top lineups from each team
    top_lineup_names = top_lineups_df.groupby('team')['lineup'].unique()
    progression_top = progression_df[
        progression_df.apply(lambda x: x['lineup'] in top_lineup_names[x['team']], axis=1)
    ]
    
    # 2. Calculate stability metrics with weighted stats
    def weighted_mean(df):
        return np.average(df['plusminus_per40'],weights = df['minutes'])
    def weighted_std(df):
        avg = weighted_mean(df)
        variance = np.average((df['plusminus_per40'] - avg) ** 2, weights=df['minutes'])
        return np.sqrt(variance)

    stability_stats = progression_top.groupby(['team', 'lineup'],group_keys = False).apply(
        lambda x : pd.Series({
            'minutes_sum': x['minutes'].sum(),
            'minutes_count': len(x),
            'minutes_std': x['minutes'].std(),
            'plusminus_per40_mean': weighted_mean(x),
            'plusminus_per40_std': weighted_std(x),
            'netrating_mean': np.average(x['netrating'], weights=x['minutes']),
            'netrating_std': np.sqrt(np.average((x['netrating']-np.average(x['netrating'], weights=x['minutes']))**2, 
                                              weights=x['minutes']))
        })
    ).reset_index()

    # Flatten multi-index columns
   # stability_stats.columns = ['_'.join(col).strip('_') if isinstance(col, tuple) else col for col in stability_stats.columns.values]
    
    # 3. Calculate coefficient of variation
    stability_stats['plusminus_per40_cv'] = (stability_stats['plusminus_per40_std'] / 
                                     stability_stats['plusminus_per40_mean']).abs().fillna(0)
    stability_stats['netrating_cv'] = (stability_stats['netrating_std'] /
                                     stability_stats['netrating_mean']).abs().fillna(0)
    
    
    # 4. Determine minimum sample sizes
    min_samples = []
    for (team, lineup), group in progression_top.groupby(['team', 'lineup']):
        # Calculate PROPER cumulative plusminus_per40
        cum_minutes = group['minutes'].cumsum()
        cum_plusminus = group['plusminus'].cumsum()
        cum_p40 = (cum_plusminus/cum_minutes)*40
        
        # Check for stabilization
        stabilized = False
        # Iterate through cumulative minutes and p40
        for i in range(1, len(cum_minutes)):
            if abs(cum_p40.iloc[i] - cum_p40.iloc[i-1]) < 5 and abs(cum_minutes.iloc[i]-cum_minutes.iloc[i-1])>2:  # <5 p40 change and more than 2 minutes change
                min_samples.append({
                    'team': team,
                    'lineup': lineup,
                    'stabilized_at': cum_minutes.iloc[i],
                    'stabilized_p40': cum_p40.iloc[i],
                    'final_plusminus_per40': (group['plusminus'].sum() / group['minutes'].sum()) * 40,
                    'total_minutes': cum_minutes.iloc[-1]
                })
                stabilized = True
                #print(f"Stabilized: {team} - {lineup} at {cum_minutes.iloc[i]} minutes with net rating {cum_p40.iloc[-1]}")
                break
        
        
        
        min_samples_df = pd.DataFrame(min_samples)
    # Calculate % of lineups that stabilized
    num_stabilized = len(min_samples)
    num_total = stability_stats.shape[0]
    percent_stabilized = round(100 * num_stabilized / num_total, 2)
    print(f"Percentage of lineups that stabilized: {percent_stabilized}%")

    return stability_stats, min_samples_df

# %% [markdown]
# ## Run analysis pipeline - Min_Samples Table

# %%
stability_stats, min_samples = analyze_conference(combined_progression, combined_top_lineups)
numerical_cols = stability_stats.select_dtypes(include=['float64']).columns
stability_stats[numerical_cols] = stability_stats[numerical_cols].round(2)

numerical_cols = min_samples.select_dtypes(include=['float64']).columns
min_samples[numerical_cols] = min_samples[numerical_cols].round(2)
display(min_samples)
#print('\n',min_samples.iloc[149])
# Out:
# Percentage of lineups that stabilized: 56.45%
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:578: RuntimeWarning: invalid value encountered in multiply
#   avg = avg_as_array = np.multiply(a, wgt,
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_59306/2539824208.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stability_stats = progression_top.groupby(['team', 'lineup'],group_keys = False).apply(
#               team                    lineup  stabilized_at  stabilized_p40  \
# 0            Akron  EHAL-AMOB-SBRO-MVEJ-NCLA          42.13           11.39
# 1            Akron  EHAL-AMOB-ZRAS-MVEJ-NCLA          47.51          -25.26
# 2            Akron  EHAL-AMOB-ZRAS-SBRO-LTAP          50.36           -6.35
# 3            Akron  EHAL-AMOB-ZRAS-SBRO-NCLA          49.15           -4.07
# 4            Akron  EHAL-ZRAS-SBRO-MVEJ-LTAP          36.08            9.98
# ..             ...                       ...            ...             ...
# 205  Western Mich.  MWAG-MASE-AKOU-HSPI-ECAR          22.97          -24.38
# 206           Yale  ALEE-CMOO-KODU-MEGG-AGUI          17.82          -13.47
# 207           Yale  ALEE-KCAP-KODU-MEGG-GTHY          24.21          -19.83
# 208           Yale  ALEE-MCHA-CMOO-KCAP-MEGG          53.54          -17.18
# 209           Yale  ALEE-MCHA-KCAP-MEGG-AGUI          21.06           11.40
#
#      final_plusminus_per40  total_minutes
# 0                    11.39          42.13
# 1                   -25.26          47.51
# 2                    -8.22          72.95
# 3                     0.00          79.56
# 4                     9.98          36.08
# ..                     ...            ...
# 205                 -24.38          22.97
# 206                 -13.47          17.82
# 207                 -18.79          29.81
# 208                 -17.18          53.54
# 209                  11.40          21.06
#
# [210 rows x 6 columns]

# %% [markdown]
# ### In case you want to reference the progression stats

# %%
display(combined_progression)

#print('\n',combined_progression.iloc[5075])
#print('\n',combined_progression.iloc[5093])
#print('\n',combined_progression.iloc[5222])
#print('\n',combined_progression.iloc[5249])
# Out:
#                         lineup  interval_num  possessions  minutes  \
# 0     EHAL-AMOB-SBRO-MVEJ-NCLA             1         1.56     0.82
# 1     KRHO-ZRAS-TCLA-SBRO-LTAP             1         7.40     3.83
# 2     KRHO-ZRAS-TCLA-MVEJ-LTAP             1        10.20     5.97
# 3     EHAL-ZRAS-TCLA-SBRO-NCLA             1         0.40     0.00
# 4     EHAL-ZRAS-SBRO-MVEJ-LTAP             1         0.40     0.27
# ...                        ...           ...          ...      ...
# 8565  EVIL-MALS-CABR-JVIL-DMEN             4         6.50     3.82
# 8566  EVIL-ATUH-CABR-JVIL-TWAL             4        17.73    10.16
# 8567  EVIL-ATUH-JVIL-DMEN-TWAL             4        97.80    56.27
# 8568  ATUH-KGAR-CABR-JVIL-TWAL             4         9.29     5.65
# 8569  EVIL-ATUH-MALS-TWAL-ACOV             4         9.43     6.14
#
#       plusminus_per40  netrating  plusminus            team conference
# 0                0.00       0.00          0           Akron        MAC
# 1              -20.89     -27.03         -2           Akron        MAC
# 2              -53.60     -78.47         -8           Akron        MAC
# 3                 inf     500.00          2           Akron        MAC
# 4              296.30     500.00          2           Akron        MAC
# ...               ...        ...        ...             ...        ...
# 8565            41.88      61.54          4  Washington St.        WCC
# 8566            66.93      95.87         17  Washington St.        WCC
# 8567            11.37      16.36         16  Washington St.        WCC
# 8568             0.00       0.00          0  Washington St.        WCC
# 8569            32.57      53.02          5  Washington St.        WCC
#
# [8570 rows x 9 columns]

# %% [markdown]
# ### In case you want to reference top_lineup stats

# %%
display(combined_top_lineups)
# Out:
#                        lineup  possessions  minutes  plusminus  \
# 0    EHAL-AMOB-ZRAS-SBRO-NCLA       134.63    79.56          0
# 1    EHAL-ZRAS-SBRO-MVEJ-NCLA       131.04    80.24         -7
# 2    EHAL-AMOB-ZRAS-SBRO-LTAP       124.94    72.95        -15
# 3    EHAL-AMOB-ZRAS-MVEJ-LTAP        94.88    54.97        -32
# 4    EHAL-AMOB-ZRAS-MVEJ-NCLA        82.41    47.51        -30
# ..                        ...          ...      ...        ...
# 367  EVIL-ATUH-MALS-DMEN-TWAL        43.34    26.22         14
# 368  EVIL-ATUH-MALS-TWAL-ACOV        40.52    24.84         -1
# 369  EVIL-KGAR-CABR-DMEN-TWAL        31.01    18.33          5
# 370  ATUH-CABR-JVIL-TWAL-ACOV        29.90    16.34         -4
# 371  EVIL-ATUH-KGAR-TWAL-ACOV        28.80    18.53          6
#
#      plusminus_per40  netrating  offrating  defrating            team  \
# 0               0.00       0.00      89.14      89.14           Akron
# 1              -3.49      -5.34      84.71      90.05           Akron
# 2              -8.22     -12.01      87.25      99.25           Akron
# 3             -23.29     -33.73      95.91     129.64           Akron
# 4             -25.26     -36.41      61.89      98.29           Akron
# ..               ...        ...        ...        ...             ...
# 367            21.36      32.30     129.20      96.90  Washington St.
# 368            -1.61      -2.47      96.24      98.71  Washington St.
# 369            10.91      16.12      99.97      83.85  Washington St.
# 370            -9.79     -13.38      70.23      83.61  Washington St.
# 371            12.95      20.84     100.71      79.87  Washington St.
#
#     conference
# 0          MAC
# 1          MAC
# 2          MAC
# 3          MAC
# 4          MAC
# ..         ...
# 367        WCC
# 368        WCC
# 369        WCC
# 370        WCC
# 371        WCC
#
# [372 rows x 10 columns]

# %% [markdown]
# ### Let's Look at lineups stabilized with at least 35 minutes and the DIFF between stabilized p40 and final_p40

# %%
min_samples35 = min_samples[min_samples['stabilized_at']>35]
min_samples35['p40_diff'] = min_samples35['final_plusminus_per40'] - min_samples35['stabilized_p40']
min_samples35['p40_diff'] = min_samples35['p40_diff'].round(2)
display(min_samples35.sort_values(by='total_minutes',ascending = False))
print(min_samples35.aggregate(
    {'p40_diff':['mean','std','max']
    }
))
# Out:
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_59306/2806793756.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_samples35['p40_diff'] = min_samples35['final_plusminus_per40'] - min_samples35['stabilized_p40']
# /var/folders/qh/zhr4gq8s5px2ff46zwfdk90hy3y30j/T/ipykernel_59306/2806793756.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_samples35['p40_diff'] = min_samples35['p40_diff'].round(2)
#               team                    lineup  stabilized_at  stabilized_p40  \
# 141       Portland  MMEE-AMAR-ESHE-MBUR-THUL         269.88           26.83
# 113     Oregon St.  KSHU-TBOL-CFER-AMAR-KREE         269.14           -2.38
# 76        LMU (CA)  BWIL-NEVA-ACLA-MHER-CHEI         317.64           -4.91
# 70        Kent St.  DGRA-MBAB-JTYL-JBAT-BDUN         192.89            9.95
# 64         Harvard  HTUR-GAND-LCHA-SGLE-EROD         132.86            6.02
# ..             ...                       ...            ...             ...
# 4            Akron  EHAL-ZRAS-SBRO-MVEJ-LTAP          36.08            9.98
# 54   Eastern Mich.  MAMA-OSMI-KLEW-OWES-SELE          35.97            6.67
# 42         Cornell  AKIL-KLAN-PENG-SPAR-RKAU          35.44          -15.80
# 164      San Diego  ARAN-HRHO-JRHO-DMOO-KHOR          35.40          -24.86
# 125           Penn  MGAY-SCAL-ASHA-SALM-KCOL          35.23            9.08
#
#      final_plusminus_per40  total_minutes  p40_diff
# 141                  23.62         416.59     -3.21
# 113                   0.80         348.67      3.18
# 76                   -4.91         317.64      0.00
# 70                   10.07         285.89      0.12
# 64                   14.85         269.28      8.83
# ..                     ...            ...       ...
# 4                     9.98          36.08      0.00
# 54                    6.67          35.97      0.00
# 42                  -15.80          35.44      0.00
# 164                 -24.86          35.40      0.00
# 125                   9.08          35.23      0.00
#
# [108 rows x 7 columns]
#        p40_diff
# mean  -0.502500
# std    4.480154
# max   13.950000

# %% [markdown]
# ## Stability Stats

# %%
display(stability_stats)
# Out:
#       team                    lineup  minutes_sum  minutes_count  minutes_std  \
# 0    Akron  EHAL-AMOB-SBRO-MVEJ-LTAP        32.87            3.0        10.39
# 1    Akron  EHAL-AMOB-SBRO-MVEJ-NCLA        42.13            4.0         9.23
# 2    Akron  EHAL-AMOB-ZRAS-MVEJ-LTAP        54.97            4.0        10.28
# 3    Akron  EHAL-AMOB-ZRAS-MVEJ-NCLA        47.51            4.0         7.45
# 4    Akron  EHAL-AMOB-ZRAS-NCLA-LTAP        28.46            3.0        13.36
# ..     ...                       ...          ...            ...          ...
# 367   Yale  ALEE-MCHA-KODU-MEGG-AGUI        23.01            3.0        11.56
# 368   Yale  ALON-MCHA-KCAP-MEGG-GTHY        15.10            2.0         7.24
# 369   Yale  MCHA-CMOO-KCAP-KODU-MEGG        15.75            1.0          NaN
# 370   Yale  MCHA-CMOO-KCAP-MEGG-MSCH        14.53            2.0         3.44
# 371   Yale  MCHA-KCAP-KODU-MEGG-GTHY        23.40            3.0         8.23
#
#      plusminus_per40_mean  plusminus_per40_std  netrating_mean  netrating_std  \
# 0                   14.60                37.92           25.70          41.43
# 1                   11.39                13.26           16.30          19.38
# 2                  -23.28                44.17          -31.77          58.03
# 3                  -25.26                29.25          -38.32          41.90
# 4                    2.81                 1.06            4.56           1.72
# ..                    ...                  ...             ...            ...
# 367                 24.34                28.37           31.92          46.07
# 368                -21.19                19.55          -36.06          43.29
# 369                -33.02                 0.00          -47.23           0.00
# 370                 30.28                13.69           38.62          16.42
# 371                -30.77                10.68          -45.63          12.48
#
#      plusminus_per40_cv  netrating_cv
# 0                  2.60          1.61
# 1                  1.16          1.19
# 2                  1.90          1.83
# 3                  1.16          1.09
# 4                  0.38          0.38
# ..                  ...           ...
# 367                1.17          1.44
# 368                0.92          1.20
# 369                0.00          0.00
# 370                0.45          0.43
# 371                0.35          0.27
#
# [372 rows x 11 columns]

# %% [markdown]
# ### In case you want to reference progression stats

# %%
display(combined_progression)
# Out:
#                         lineup  interval_num  possessions  minutes  \
# 0     EHAL-AMOB-SBRO-MVEJ-NCLA             1         1.56     0.82
# 1     KRHO-ZRAS-TCLA-SBRO-LTAP             1         7.40     3.83
# 2     KRHO-ZRAS-TCLA-MVEJ-LTAP             1        10.20     5.97
# 3     EHAL-ZRAS-TCLA-SBRO-NCLA             1         0.40     0.00
# 4     EHAL-ZRAS-SBRO-MVEJ-LTAP             1         0.40     0.27
# ...                        ...           ...          ...      ...
# 8565  EVIL-MALS-CABR-JVIL-DMEN             4         6.50     3.82
# 8566  EVIL-ATUH-CABR-JVIL-TWAL             4        17.73    10.16
# 8567  EVIL-ATUH-JVIL-DMEN-TWAL             4        97.80    56.27
# 8568  ATUH-KGAR-CABR-JVIL-TWAL             4         9.29     5.65
# 8569  EVIL-ATUH-MALS-TWAL-ACOV             4         9.43     6.14
#
#       plusminus_per40  netrating  plusminus            team conference
# 0                0.00       0.00          0           Akron        MAC
# 1              -20.89     -27.03         -2           Akron        MAC
# 2              -53.60     -78.47         -8           Akron        MAC
# 3                 inf     500.00          2           Akron        MAC
# 4              296.30     500.00          2           Akron        MAC
# ...               ...        ...        ...             ...        ...
# 8565            41.88      61.54          4  Washington St.        WCC
# 8566            66.93      95.87         17  Washington St.        WCC
# 8567            11.37      16.36         16  Washington St.        WCC
# 8568             0.00       0.00          0  Washington St.        WCC
# 8569            32.57      53.02          5  Washington St.        WCC
#
# [8570 rows x 9 columns]

# %% [markdown]
# ## Generate Key Insights

# %%
def generate_wcc_insights(stats_df, min_samples_df):
    """Print actionable conference insights"""
    # Conference averages
    # Calculate without extreme values
    q1 = stats_df['plusminus_per40_cv'].quantile(0.25)
    q3 = stats_df['plusminus_per40_cv'].quantile(0.75)
    iqr = q3 - q1
    filtered = stats_df[stats_df['plusminus_per40_cv'] <= (q3 + 1.5*iqr)]
    #print(filtered['plusminus_per40_cv'].median())


    avg_stabilization = min_samples_df['stabilized_at'].median()
    avg_cv = filtered['plusminus_per40_cv'].median()

    print(f"=== WCC Conference Insights ===\n")
    print(f"1. Lineups typically stabilize after {avg_stabilization:.0f} minutes")
    print(f"   - Median coefficient of variation: {avg_cv:.2f}")
    
    # Team rankings
    team_stability = filtered.groupby('team')['plusminus_per40_cv'].mean().sort_values()
    print("\n2. Teams by lineup stability (lower CV is better):")
    print(team_stability.round(2))
    
    # Sample size recommendations
    print("\n3. Evaluation guidelines:")
    print(f"   - <{avg_stabilization:.0f} minutes: Insufficient sample")
    print(f"   - {avg_stabilization:.0f}-100 minutes: Preliminary assessment")
    print("   - 100+ minutes: Reliable evaluation")

# %%
generate_wcc_insights(stability_stats, min_samples)
# Out:
# === WCC Conference Insights ===
#
# 1. Lineups typically stabilize after 35 minutes
#    - Median coefficient of variation: 1.17
#
# 2. Teams by lineup stability (lower CV is better):
# team
# Princeton            0.80
# San Francisco        1.01
# Buffalo              1.07
# Harvard              1.10
# San Diego            1.15
# Bowling Green        1.19
# NIU                  1.22
# Miami (OH)           1.26
# Ohio                 1.28
# Cornell              1.31
# Dartmouth            1.36
# Akron                1.38
# Yale                 1.53
# Eastern Mich.        1.54
# Saint Mary's (CA)    1.57
# Gonzaga              1.60
# Santa Clara          1.71
# Columbia             1.73
# Western Mich.        1.75
# Pepperdine           1.81
# Ball St.             1.85
# Toledo               2.01
# Washington St.       2.03
# Portland             2.04
# Pacific              2.23
# Oregon St.           2.27
# Brown                2.30
# LMU (CA)             2.32
# Central Mich.        2.34
# Penn                 2.41
# Kent St.             2.57
# Name: plusminus_per40_cv, dtype: float64
#
# 3. Evaluation guidelines:
#    - <35 minutes: Insufficient sample
#    - 35-100 minutes: Preliminary assessment
#    - 100+ minutes: Reliable evaluation

# %% [markdown]
# ## "Use" Actionable Insights

# %% [markdown]
# #### Note that there are 372 distinct lineups in this dataset

# %%
#lineups with more than avg_stabilization minutes played full season sorted by plusminus_per40 and with a cv of less than 3
avg_stabilization = 35

lineups_over_50_full_season = stability_stats[(stability_stats['minutes_sum'] > avg_stabilization) & (stability_stats['plusminus_per40_cv'] < 3)][['lineup', 'team', 'minutes_sum', 'plusminus_per40_mean','plusminus_per40_cv']]
lineups_over_50_full_season_sorted = lineups_over_50_full_season.sort_values(by='plusminus_per40_mean', ascending=False)
styled_full_season_sorted = lineups_over_50_full_season_sorted.style.background_gradient(
    cmap='RdYlGn',
    subset=['plusminus_per40_mean']
). format({
    'plusminus_per40_mean': '{:.1f}',
    'minutes_sum': '{:.0f}',
    'plusminus_per40_cv': '{:.1f}'
})
display(styled_full_season_sorted)

print("\n Number of lineups in this criteria: ", len(lineups_over_50_full_season))
print("'%' of lineups that meet this criteria", round(len(lineups_over_50_full_season)/372*100,2),'%')
# Out:
# <style type="text/css">
# #T_bbe3e_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bbe3e_row1_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_bbe3e_row2_col3 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_bbe3e_row3_col3 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_bbe3e_row4_col3 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_bbe3e_row5_col3, #T_bbe3e_row6_col3 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_bbe3e_row7_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_bbe3e_row8_col3, #T_bbe3e_row9_col3 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_bbe3e_row10_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_bbe3e_row11_col3, #T_bbe3e_row12_col3 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_bbe3e_row13_col3 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_bbe3e_row14_col3 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_bbe3e_row15_col3 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_bbe3e_row16_col3 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_bbe3e_row17_col3 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_bbe3e_row18_col3, #T_bbe3e_row19_col3 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_bbe3e_row20_col3 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_bbe3e_row21_col3 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_bbe3e_row22_col3, #T_bbe3e_row23_col3, #T_bbe3e_row24_col3 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_bbe3e_row25_col3, #T_bbe3e_row26_col3 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_bbe3e_row27_col3 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_bbe3e_row28_col3 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_bbe3e_row29_col3 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_bbe3e_row30_col3 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_bbe3e_row31_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_bbe3e_row32_col3, #T_bbe3e_row33_col3, #T_bbe3e_row34_col3 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_bbe3e_row35_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_bbe3e_row36_col3, #T_bbe3e_row37_col3 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_bbe3e_row38_col3, #T_bbe3e_row39_col3 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_bbe3e_row40_col3 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_bbe3e_row41_col3 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_bbe3e_row42_col3, #T_bbe3e_row43_col3 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_bbe3e_row44_col3, #T_bbe3e_row45_col3 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_bbe3e_row46_col3, #T_bbe3e_row47_col3, #T_bbe3e_row48_col3 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_bbe3e_row49_col3, #T_bbe3e_row50_col3, #T_bbe3e_row51_col3, #T_bbe3e_row52_col3, #T_bbe3e_row53_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_bbe3e_row54_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_bbe3e_row55_col3, #T_bbe3e_row56_col3, #T_bbe3e_row57_col3, #T_bbe3e_row58_col3, #T_bbe3e_row59_col3 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_bbe3e_row60_col3, #T_bbe3e_row61_col3, #T_bbe3e_row62_col3, #T_bbe3e_row63_col3 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_bbe3e_row64_col3 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_bbe3e_row65_col3 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_bbe3e_row66_col3, #T_bbe3e_row67_col3, #T_bbe3e_row68_col3 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_bbe3e_row69_col3, #T_bbe3e_row70_col3 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_bbe3e_row71_col3 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_bbe3e_row72_col3, #T_bbe3e_row73_col3 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_bbe3e_row74_col3, #T_bbe3e_row75_col3 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_bbe3e_row76_col3, #T_bbe3e_row77_col3 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_bbe3e_row78_col3, #T_bbe3e_row79_col3, #T_bbe3e_row80_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_bbe3e_row81_col3 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_bbe3e_row82_col3, #T_bbe3e_row83_col3 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_bbe3e_row84_col3 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_bbe3e_row85_col3, #T_bbe3e_row86_col3 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_bbe3e_row87_col3, #T_bbe3e_row88_col3 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_bbe3e_row89_col3, #T_bbe3e_row90_col3, #T_bbe3e_row91_col3 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_bbe3e_row92_col3 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_bbe3e_row93_col3 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_bbe3e_row94_col3, #T_bbe3e_row95_col3, #T_bbe3e_row96_col3 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_bbe3e_row97_col3, #T_bbe3e_row98_col3 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_bbe3e_row99_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_bbe3e_row100_col3 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_bbe3e_row101_col3 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_bbe3e_row102_col3, #T_bbe3e_row103_col3, #T_bbe3e_row104_col3 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_bbe3e_row105_col3, #T_bbe3e_row106_col3 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_bbe3e_row107_col3, #T_bbe3e_row108_col3 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_bbe3e_row109_col3 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_bbe3e_row110_col3, #T_bbe3e_row111_col3, #T_bbe3e_row112_col3 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_bbe3e_row113_col3, #T_bbe3e_row114_col3 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_bbe3e_row115_col3 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_bbe3e_row116_col3, #T_bbe3e_row117_col3 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_bbe3e_row118_col3 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_bbe3e_row119_col3, #T_bbe3e_row120_col3 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_bbe3e_row121_col3, #T_bbe3e_row122_col3 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_bbe3e_row123_col3 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_bbe3e_row124_col3 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_bbe3e_row125_col3 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_bbe3e_row126_col3, #T_bbe3e_row127_col3 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_bbe3e_row128_col3 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_bbe3e_row129_col3 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_bbe3e_row130_col3, #T_bbe3e_row131_col3 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_bbe3e_row132_col3 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_bbe3e_row133_col3 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_bbe3e_row134_col3 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_bbe3e_row135_col3 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_bbe3e_row136_col3 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_bbe3e_row137_col3 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_bbe3e_row138_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_bbe3e_row139_col3, #T_bbe3e_row140_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bbe3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbe3e_level0_col0" class="col_heading level0 col0" >lineup</th>
#       <th id="T_bbe3e_level0_col1" class="col_heading level0 col1" >team</th>
#       <th id="T_bbe3e_level0_col2" class="col_heading level0 col2" >minutes_sum</th>
#       <th id="T_bbe3e_level0_col3" class="col_heading level0 col3" >plusminus_per40_mean</th>
#       <th id="T_bbe3e_level0_col4" class="col_heading level0 col4" >plusminus_per40_cv</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbe3e_level0_row0" class="row_heading level0 row0" >132</th>
#       <td id="T_bbe3e_row0_col0" class="data
#  Number of lineups in this criteria:  141
# '%' of lineups that meet this criteria 37.9 %

# %% [markdown]
# ## Lastly, just for fun, let's look at team combo pairs

# %%
all_team_pairs = []

for team, group in stability_stats.groupby('team'):
    # Step 1: Get top 2 lineups by minutes for this team
    top_2_lineups = (
        group.sort_values('minutes_sum', ascending=False)
        .head(2)['lineup'].tolist()
    )
    top_2_data = group[group['lineup'].isin(top_2_lineups)]

    # Step 2: Get players in top 2 lineups (ordered, deduped)
    top_players_ordered = []
    for lu in top_2_lineups:
        top_players_ordered += lu.split('-')
    top_players_ordered = list(dict.fromkeys(top_players_ordered))

    # Step 3: Build player pair combos for all top 2 lineups
    player_combos = []
    for _, row in top_2_data.iterrows():
        players = row['lineup'].split('-')
        for i in range(len(players)):
            for j in range(i+1, len(players)):
                player_combos.append({
                    'team': team,
                    'player1': players[i],
                    'player2': players[j],
                    'plusminus_per40': row['plusminus_per40_mean'],
                    'minutes': row['minutes_sum']
                })
    combo_df = pd.DataFrame(player_combos)
    if combo_df.empty:
        continue
    combo_df = combo_df[combo_df['minutes']>150]
    # Step 4: Aggregate across all appearances (mean plusminus, sum minutes)
    top_pairs = (
        combo_df.groupby(['team', 'player1', 'player2'])
        .agg({'plusminus_per40': 'mean', 'minutes': 'sum'})
        .reset_index()
    )

    # Step 5: Filter to pairs where both players are in top 2 lineups
    filtered_pairs = top_pairs[
        top_pairs['player1'].isin(top_players_ordered) &
        top_pairs['player2'].isin(top_players_ordered)
    ].copy()

    # Step 6: Sort by player1’s appearance order
    filtered_pairs['player1'] = pd.Categorical(filtered_pairs['player1'],
                                               categories=top_players_ordered,
                                               ordered=True)
    filtered_pairs = filtered_pairs.sort_values(['player1', 'minutes'], ascending=[True, False])

    all_team_pairs.append(filtered_pairs)

# Combine all teams
final_pairs = pd.concat(all_team_pairs, ignore_index=True)

# Style and display
styled_pairs = final_pairs.style.background_gradient(
    cmap='RdYlGn',
    subset=['plusminus_per40']
).format({
    'plusminus_per40': '{:.1f}',
    'minutes': '{:.0f}',
})

display(styled_pairs)
# Out:
# <style type="text/css">
# #T_b21bb_row0_col3, #T_b21bb_row1_col3, #T_b21bb_row2_col3, #T_b21bb_row3_col3, #T_b21bb_row4_col3, #T_b21bb_row5_col3, #T_b21bb_row6_col3, #T_b21bb_row7_col3, #T_b21bb_row8_col3, #T_b21bb_row9_col3, #T_b21bb_row80_col3, #T_b21bb_row81_col3, #T_b21bb_row82_col3, #T_b21bb_row83_col3, #T_b21bb_row84_col3, #T_b21bb_row85_col3, #T_b21bb_row86_col3, #T_b21bb_row87_col3, #T_b21bb_row88_col3, #T_b21bb_row89_col3 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_b21bb_row10_col3, #T_b21bb_row11_col3, #T_b21bb_row12_col3, #T_b21bb_row13_col3, #T_b21bb_row14_col3, #T_b21bb_row15_col3, #T_b21bb_row16_col3, #T_b21bb_row17_col3, #T_b21bb_row18_col3, #T_b21bb_row19_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_b21bb_row20_col3, #T_b21bb_row21_col3, #T_b21bb_row22_col3, #T_b21bb_row23_col3, #T_b21bb_row24_col3, #T_b21bb_row25_col3, #T_b21bb_row26_col3, #T_b21bb_row27_col3, #T_b21bb_row28_col3, #T_b21bb_row29_col3 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_b21bb_row30_col3, #T_b21bb_row31_col3, #T_b21bb_row32_col3, #T_b21bb_row33_col3, #T_b21bb_row34_col3, #T_b21bb_row35_col3, #T_b21bb_row36_col3, #T_b21bb_row37_col3, #T_b21bb_row38_col3, #T_b21bb_row39_col3 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_b21bb_row40_col3, #T_b21bb_row41_col3, #T_b21bb_row42_col3, #T_b21bb_row43_col3, #T_b21bb_row44_col3, #T_b21bb_row45_col3, #T_b21bb_row46_col3, #T_b21bb_row47_col3, #T_b21bb_row48_col3, #T_b21bb_row49_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_b21bb_row50_col3, #T_b21bb_row51_col3, #T_b21bb_row52_col3, #T_b21bb_row53_col3, #T_b21bb_row54_col3, #T_b21bb_row55_col3, #T_b21bb_row56_col3, #T_b21bb_row57_col3, #T_b21bb_row58_col3, #T_b21bb_row59_col3 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_b21bb_row60_col3, #T_b21bb_row61_col3, #T_b21bb_row62_col3, #T_b21bb_row63_col3, #T_b21bb_row64_col3, #T_b21bb_row65_col3, #T_b21bb_row66_col3, #T_b21bb_row67_col3, #T_b21bb_row68_col3, #T_b21bb_row69_col3 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_b21bb_row70_col3, #T_b21bb_row71_col3, #T_b21bb_row72_col3, #T_b21bb_row73_col3, #T_b21bb_row74_col3, #T_b21bb_row75_col3, #T_b21bb_row76_col3, #T_b21bb_row77_col3, #T_b21bb_row78_col3, #T_b21bb_row79_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_b21bb_row90_col3, #T_b21bb_row91_col3, #T_b21bb_row92_col3, #T_b21bb_row95_col3, #T_b21bb_row96_col3, #T_b21bb_row101_col3 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_b21bb_row93_col3, #T_b21bb_row97_col3, #T_b21bb_row99_col3, #T_b21bb_row100_col3 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_b21bb_row94_col3, #T_b21bb_row98_col3, #T_b21bb_row102_col3, #T_b21bb_row103_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_b21bb_row104_col3, #T_b21bb_row105_col3, #T_b21bb_row106_col3, #T_b21bb_row109_col3, #T_b21bb_row110_col3, #T_b21bb_row113_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_b21bb_row107_col3, #T_b21bb_row111_col3, #T_b21bb_row114_col3, #T_b21bb_row116_col3 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_b21bb_row108_col3, #T_b21bb_row112_col3, #T_b21bb_row115_col3, #T_b21bb_row117_col3 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_b21bb_row118_col3, #T_b21bb_row119_col3, #T_b21bb_row120_col3, #T_b21bb_row121_col3, #T_b21bb_row122_col3, #T_b21bb_row123_col3, #T_b21bb_row124_col3, #T_b21bb_row125_col3, #T_b21bb_row126_col3, #T_b21bb_row127_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_b21bb_row128_col3, #T_b21bb_row129_col3, #T_b21bb_row130_col3, #T_b21bb_row131_col3, #T_b21bb_row132_col3, #T_b21bb_row133_col3, #T_b21bb_row134_col3, #T_b21bb_row135_col3, #T_b21bb_row136_col3, #T_b21bb_row137_col3 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_b21bb_row138_col3, #T_b21bb_row139_col3, #T_b21bb_row140_col3, #T_b21bb_row141_col3, #T_b21bb_row142_col3, #T_b21bb_row143_col3, #T_b21bb_row144_col3, #T_b21bb_row145_col3, #T_b21bb_row146_col3, #T_b21bb_row147_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_b21bb_row148_col3, #T_b21bb_row149_col3, #T_b21bb_row150_col3, #T_b21bb_row151_col3, #T_b21bb_row152_col3, #T_b21bb_row153_col3, #T_b21bb_row154_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b21bb_row155_col3, #T_b21bb_row156_col3, #T_b21bb_row157_col3, #T_b21bb_row158_col3, #T_b21bb_row159_col3, #T_b21bb_row160_col3, #T_b21bb_row161_col3, #T_b21bb_row162_col3, #T_b21bb_row163_col3, #T_b21bb_row164_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b21bb_row165_col3, #T_b21bb_row166_col3, #T_b21bb_row167_col3, #T_b21bb_row168_col3, #T_b21bb_row169_col3, #T_b21bb_row170_col3, #T_b21bb_row171_col3, #T_b21bb_row172_col3, #T_b21bb_row173_col3, #T_b21bb_row174_col3 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_b21bb_row175_col3, #T_b21bb_row176_col3, #T_b21bb_row177_col3, #T_b21bb_row178_col3, #T_b21bb_row179_col3, #T_b21bb_row180_col3, #T_b21bb_row181_col3, #T_b21bb_row182_col3, #T_b21bb_row183_col3, #T_b21bb_row184_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_b21bb_row185_col3, #T_b21bb_row186_col3, #T_b21bb_row187_col3, #T_b21bb_row190_col3, #T_b21bb_row191_col3, #T_b21bb_row194_col3 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_b21bb_row188_col3, #T_b21bb_row192_col3, #T_b21bb_row195_col3, #T_b21bb_row197_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_b21bb_row189_col3, #T_b21bb_row193_col3, #T_b21bb_row196_col3, #T_b21bb_row198_col3 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_b21bb_row199_col3, #T_b21bb_row200_col3, #T_b21bb_row201_col3, #T_b21bb_row202_col3, #T_b21bb_row203_col3, #T_b21bb_row204_col3, #T_b21bb_row205_col3, #T_b21bb_row206_col3, #T_b21bb_row207_col3, #T_b21bb_row208_col3 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_b21bb_row209_col3, #T_b21bb_row210_col3, #T_b21bb_row211_col3, #T_b21bb_row212_col3, #T_b21bb_row213_col3, #T_b21bb_row214_col3, #T_b21bb_row215_col3, #T_b21bb_row216_col3, #T_b21bb_row217_col3, #T_b21bb_row218_col3 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b21bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b21bb_level0_col0" class="col_heading level0 col0" >team</th>
#       <th id="T_b21bb_level0_col1" class="col_heading level0 col1" >player1</th>
#       <th id="T_b21bb_level0_col2" class="col_heading level0 col2" >player2</th>
#       <th id="T_b21bb_level0_col3" class="col_heading level0 col3" >plusminus_per40</th>
#       <th id="T_b21bb_level0_col4" class="col_heading level0 col4" >minutes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b21bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b21bb_row0_col0" class="data row0 col0" >Ball St.</td>
#       <td id="T_b21bb_row0_col1" class="data row0 col1" >LAUS</td>
#       <td id="T_b21bb_row0_col2" class="data row0 col2" >ABEC</td>
#       <td id="T_b21bb_row0_col3" class="data row0 col3" >10.0</td>
#       <td id="T_b21bb_row0_col4" class="data row0 col4" >279</td>
#     </tr>
#     <tr>
#       <th id="T_b21bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b21bb_row1_col0" class="data row1 col0" >Ball St.</td>
#       <td id="T_b21bb_row1_col1" class="data row1 col1" >LAUS</td>
#       <td id="T_b21bb_row1_col2" class="data row1 col2" >ARIC</td>
#       <td id="T_b21bb_row1_col3" class="data row1 col3" >10.0</td>
#       <td id="T_b21bb_row1_col4" class="data row1 col4" >279</td>
#     </tr>
#     <tr>
#       <th id="T_b21bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b21bb_row2_col0" class="data row2 col0" >Ball St.</td>
#       <td id="T_b21bb_row2_col1" class="data row2 col1" >LAUS</td>
#       <td id="T_b21bb_row2_col2" class="data row2 col2" >MBIS</td>
#       <td id="T_b21bb_row2_col3" class="data row2 col3" >10.0</td>
#       <td id="T_b21bb_row2_col4" class="data row2 col4" >279</td>
#     </tr>
#     <tr>
#       <th id="T_b21bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b21bb_row3_col0" class="data row3 col0

# %% [markdown]
# ## Save Results

# %%
stability_stats.to_csv('output/wcc_stability_stats.csv', index=False)
min_samples.to_csv('output/wcc_min_samples.csv', index=False)
